# %% [markdown]
# # CONTENTS
#
# - IMPORTING DATA
# - EXPLORING DATA
# - DATA WRANGLING
# - DATA INTEGRITY CHECKS
# - COMBINING DATA
# - EXPORTIND DATA

# %% [markdown]
# # IMPORTING DATA

# %%
# import libraries
import pandas as pd
import numpy as np
import os
import matplotlib as plt
import seaborn as sns
import scipy

# %%
# initialize path variable
path = r'/Users/smac_/Documents/Courses/CF Data Analytics Program/Data Immersion/Achievement 4/05-2023 Instacart Basket Analysis'

# %%
# import data
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'e_orders_products_grouped.pkl'))
df_cust = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'))

# %% [markdown]
# # EXPLORING DATA

# %% [markdown]
# ## `'ords_prods_merge'` DATAFRAME

# %%
# column names & data types
ords_prods_merge.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number                int64
# orders_day_of_week          int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# product_id                 object
# add_to_cart_order           int64
# reordered                  object
# product_name               object
# aisle_id                   object
# department_id              object
# prices                    float64
# price_range                object
# busiest_day                object
# busiest_days               object
# busiest_period_of_day      object
# max_order                   int64
# loyalty_flag               object
# mean_spending             float64
# spending_flag              object
# median_frequency          float64
# frequency_flag             object
# dtype: object

# %%
# first 5 rows
ords_prods_merge.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order product_id  add_to_cart_order reordered  \
# 0                     NaN        196                  1         0
# 1                    15.0        196                  1         1
# 2                    21.0        196                  1         1
# 3                    29.0        196                  1         1
# 4                    28.0        196                  1         1
#
#   product_name  ...        price_range     busiest_day    busiest_days  \
# ...

# %%
# last 5 rows
ords_prods_merge.tail()
# Out:
#          order_id user_id  order_number  orders_day_of_week  \
# 32404854  1320836  202557            17                   2
# 32404855    31526  202557            18                   5
# 32404856   758936  203436             1                   2
# 32404857  2745165  203436             2                   3
# 32404858  3093936  205420             1                   4
#
#           order_hour_of_day  days_since_prior_order product_id  \
# 32404854                 15                     1.0      43553
# 32404855                 11                     3.0      43553
# 32404856                  7                     NaN      42338
# 32404857                  5                    15.0      42338
# 32404858                 14                     NaN      28818
#
#           add_to_cart_order reordered                   product_name  ...  \
# 32404854                  2         1            Orange Energy Shots  ...
# ...

# %%
# dataframe size
ords_prods_merge.shape
# Out:
# (32404859, 23)

# %% [markdown]
# ## `'df_cust'` DATAFRAME

# %%
# column names & data types
df_cust.dtypes
# Out:
# user_id          int64
# First Name      object
# Surnam          object
# Gender          object
# STATE           object
# Age              int64
# date_joined     object
# n_dependants     int64
# fam_status      object
# income           int64
# dtype: object

# %%
# first 5 rows
df_cust.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
# last 5 rows
df_cust.tail()
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 206204             1    married  148828
# 206205             3    married  168639
# 206206             2    married   53374
# 206207             1    married   99799
# 206208             1    married   57095

# %%
# dataframe size
df_cust.shape
# Out:
# (206209, 10)

# %% [markdown]
# # DATA WRANGLING

# %% [markdown]
# ## `'df_cust'` DATAFRAME

# %%
# drop unnecessary columns
df_cust_updated_a = df_cust.drop(columns = ['First Name', 'Surnam'])

# %% [markdown]
# These columns were removed to protect the individuals' privacy by ensuring their data cannot be traced back to them.

# %%
# first 5 rows
df_cust_updated_a.head()
# Out:
#    user_id  Gender       STATE  Age date_joined  n_dependants fam_status  \
# 0    26711  Female    Missouri   48    1/1/2017             3    married
# 1    33890  Female  New Mexico   36    1/1/2017             0     single
# 2    65803    Male       Idaho   35    1/1/2017             2    married
# 3   125935  Female        Iowa   40    1/1/2017             0     single
# 4   130797  Female    Maryland   26    1/1/2017             1    married
#
#    income
# 0  165665
# 1   59285
# 2   99568
# 3   42049
# 4   40374

# %%
# rename colums
new_column_names = {'user_id' : 'user_id', 'Gender' : 'gender', 'STATE' : 'state', 'Age' : 'age', 'date_joined' : 'date_joined', 'n_dependants' : 'dependants', 'fam_status' : 'marital_status', 'income' : 'income'}
df_cust_updated_b = df_cust_updated_a.rename(columns = new_column_names)

# %% [markdown]
# The column headers were renamed to improve clarity and consistency.

# %%
# first 5 rows
df_cust_updated_b.head()
# Out:
#    user_id  gender       state  age date_joined  dependants marital_status  \
# 0    26711  Female    Missouri   48    1/1/2017           3        married
# 1    33890  Female  New Mexico   36    1/1/2017           0         single
# 2    65803    Male       Idaho   35    1/1/2017           2        married
# 3   125935  Female        Iowa   40    1/1/2017           0         single
# 4   130797  Female    Maryland   26    1/1/2017           1        married
#
#    income
# 0  165665
# 1   59285
# 2   99568
# 3   42049
# 4   40374

# %%
# cast nominal columns as string
df_cust_updated_b['user_id'] = df_cust_updated_b['user_id'].astype(str)

# %% [markdown]
# The column `'user_id'` in the dataframe was casted as *string* since it can't be used to perform mathematical operations.

# %% [markdown]
# # DATA INTEGRITY CHECKS

# %% [markdown]
# ## `'df_cust_updated_b'` DATAFRAME

# %%
# summary stats
df_cust_updated_b.describe()
# Out:
#                  age     dependants         income
# count  206209.000000  206209.000000  206209.000000
# mean       49.501646       1.499823   94632.852548
# std        18.480962       1.118433   42473.786988
# min        18.000000       0.000000   25903.000000
# 25%        33.000000       0.000000   59874.000000
# 50%        49.000000       1.000000   93547.000000
# 75%        66.000000       3.000000  124244.000000
# max        81.000000       3.000000  593901.000000

# %% [markdown]
# The accuracy of the numeric columns in the dataframe appears to be satisfactory. However, it is worth noting that the `'income'` column exhibits a significantly high standard deviation. This suggests the presence of potential extreme values that might be influencing the overall variability of the data.

# %%
# identify missing values in all the columns
df_cust_updated_b.isnull().sum()
# Out:
# user_id           0
# gender            0
# state             0
# age               0
# date_joined       0
# dependants        0
# marital_status    0
# income            0
# dtype: int64

# %% [markdown]
# No missing values were found.

# %%
# check for mixed-type columns
for col in df_cust_updated_b.columns.tolist():
  weird = (df_cust_updated_b[[col]].applymap(type) != df_cust_updated_b[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust_updated_b[weird]) > 0:
    print (col)

# %% [markdown]
# No mixed-type columns were found.

# %%
# identify full duplicates
df_cust_updated_b[df_cust_updated_b.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, gender, state, age, date_joined, dependants, marital_status, income]
# Index: []

# %% [markdown]
# No full duplicates were found.

# %% [markdown]
# ## `'ords_prods_merge'` DATAFRAME

# %%
# summary stats
ords_prods_merge.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count  3.240486e+07        3.240486e+07       3.240486e+07
# mean   1.714230e+01        2.738867e+00       1.342515e+01
# std    1.753532e+01        2.090077e+00       4.246380e+00
# min    1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.100000e+01        3.000000e+00       1.300000e+01
# 75%    2.400000e+01        5.000000e+00       1.600000e+01
# max    9.900000e+01        6.000000e+00       2.300000e+01
#
#        days_since_prior_order  add_to_cart_order        prices     max_order  \
# count            3.032876e+07       3.240486e+07  3.240486e+07  3.240486e+07
# mean             1.110408e+01       8.352547e+00  7.790932e+00  3.305217e+01
# std              8.779064e+00       7.127071e+00  4.241476e+00  2.515525e+01
# min              0.000000e+00       1.000000e+00  1.000000e+00  1.000000e+00
# ...

# %% [markdown]
# The accuracy of the numeric columns in the dataframe appears to be satisfactory.

# %%
# identify missing values in all the columns
ords_prods_merge.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# orders_day_of_week              0
# order_hour_of_day               0
# days_since_prior_order    2076096
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# product_name                    0
# aisle_id                        0
# department_id                   0
# prices                          0
# price_range                     0
# busiest_day                     0
# busiest_days                    0
# busiest_period_of_day           0
# max_order                       0
# loyalty_flag                    0
# mean_spending                   0
# spending_flag                   0
# median_frequency                5
# frequency_flag                  5
# dtype: int64

# %%
# rows containing missing values in 'median_frequency'
ords_prods_merge[ords_prods_merge['median_frequency'].isnull() == True]
# Out:
#          order_id user_id  order_number  orders_day_of_week  \
# 13645692   895835  159838             1                   0
# 17251990   895835  159838             1                   0
# 17622767   895835  159838             1                   0
# 24138593   895835  159838             1                   0
# 25880002   895835  159838             1                   0
#
#           order_hour_of_day  days_since_prior_order product_id  \
# 13645692                 17                     NaN      10749
# 17251990                 17                     NaN      33401
# 17622767                 17                     NaN      23695
# 24138593                 17                     NaN      21334
# 25880002                 17                     NaN      22198
#
#           add_to_cart_order reordered  \
# 13645692                  3         0
# 17251990                  6         0
# 17622767                  2         0
# 24138593                  5         0
# ...

# %% [markdown]
# The values in the `'days_since_prior_order'` column were utilized to calculate the `'median_frequency'` and `'frequency_flag'` columns. The absence of values in the derived columns can be attributed to missing values in the original column. It was inferred that these missing values could indicate new customers who have not yet placed any orders.

# %%
# check for mixed-type columns
for col in ords_prods_merge.columns.tolist():
  weird = (ords_prods_merge[[col]].applymap(type) != ords_prods_merge[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (ords_prods_merge[weird]) > 0:
    print (col)
# Out:
# frequency_flag

# %% [markdown]
# The mixed-type nature of the `'frequency_flag'` column can be attributed to the presence of missing values within it.

# %%
# identify full duplicates
ords_prods_merge[ords_prods_merge.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, prices, price_range, busiest_day, busiest_days, busiest_period_of_day, max_order, loyalty_flag, mean_spending, spending_flag, median_frequency, frequency_flag]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# No full duplicates were found.

# %% [markdown]
# # COMBINING DATA

# %%
# merge 'df_cust_updated_b' & 'ords_prods_merge' dataframes on 'user_id' (matching records only)
ords_prods_cust_merged = ords_prods_merge.merge(df_cust_updated_b, on = 'user_id', indicator = False)

# %%
# first 5 rows
ords_prods_cust_merged.head()
# Out:
#   order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329       1             1                   2                  8
# 1  2398795       1             2                   3                  7
# 2   473747       1             3                   3                 12
# 3  2254736       1             4                   4                  7
# 4   431534       1             5                   4                 15
#
#    days_since_prior_order product_id  add_to_cart_order reordered  \
# 0                     NaN        196                  1         0
# 1                    15.0        196                  1         1
# 2                    21.0        196                  1         1
# 3                    29.0        196                  1         1
# 4                    28.0        196                  1         1
#
#   product_name  ... spending_flag median_frequency         frequency_flag  \
# ...

# %%
# dataframe size
ords_prods_cust_merged.shape
# Out:
# (32404859, 30)

# %% [markdown]
# # EXPORTING DATA

# %%
# export dataframe as pickle
ords_prods_cust_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'f_orders_products_all.pkl'))
