# %% [markdown]
# # CONTENTS
#
# - IMPORTING DATA
# - EXPLORING DATA

# %% [markdown]
# # IMPORTING DATA

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# initialize path variable
path = r'/Users/smac_/Documents/courses/CF Data Analytics Program/Data Immersion/Achievement 4/05-2023 Instacart Basket Analysis'

# %%
# import data
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv' ), usecols = vars_list)
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = 0)

# %% [markdown]
# # EXPLORING DATA

# %% [markdown]
# ## `'df_ords'` DATAFRAME

# %%
# first 5 rows
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# last 5 rows
df_ords.tail()
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 3421078                    29.0
# 3421079                    30.0
# 3421080                    18.0
# 3421081                     7.0
# 3421082                    30.0

# %%
# dataframe size
df_ords.shape
# Out:
# (3421083, 6)

# %% [markdown]
# ## `'df_prods'` DATAFRAME

# %%
# first 20 rows
df_prods.head(20)
# Out:
#                                                  product_name  aisle_id  \
# product_id
# 1                                  Chocolate Sandwich Cookies        61
# 2                                            All-Seasons Salt       104
# 3                        Robust Golden Unsweetened Oolong Tea        94
# 4           Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 5                                   Green Chile Anytime Sauce         5
# 6                                                Dry Nose Oil        11
# 7                              Pure Coconut Water With Orange        98
# 8                           Cut Russet Potatoes Steam N' Mash       116
# 9                           Light Strawberry Blueberry Yogurt       120
# 10             Sparkling Orange Juice & Prickly Pear Beverage       115
# 11                                          Peach Mango Juice        31
# 12                                 Chocolate Fudge Layer Cake       119
# ...

# %%
# last 35 rows
df_prods.tail(35)
# Out:
#                                                  product_name  aisle_id  \
# product_id
# 49654                        Teriyaki Sauce, Sesame, Original         5
# 49655                                             Apple Cider        98
# 49656                              Masada Kosher Pocket Bread       128
# 49657                                       Cabernet Tomatoes        83
# 49658                              Brie with Herbs Foil Wedge         2
# 49659                                 Organic Creamed Coconut        17
# 49660                             Professionals Sleek Shampoo        22
# 49661                                                   Porto       134
# 49662                            Bacon Cheddar Pretzel Pieces       107
# 49663       Ultra Protein Power Crunch Peanut Butter N' Ho...        57
# 49664                          Lemon Cayenne Drinking Vinegar       100
# 49665           Super Dark Coconut Ash & Banana Chocolate Bar        45
# ...

# %%
# column names
df_prods.columns
# Out:
# Index(['product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
# dataframe size
df_prods.shape
# Out:
# (49693, 4)

# %% [markdown]
# ### WHAT IS THE MAXIMUM VALUE IN `'aisle_id'`?

# %%
# summary stats
df_prods.describe()
# Out:
#            aisle_id  department_id        prices
# count  49693.000000   49693.000000  49693.000000
# mean      67.770249      11.728433      9.994136
# std       38.316774       5.850282    453.519686
# min        1.000000       1.000000      1.000000
# 25%       35.000000       7.000000      4.100000
# 50%       69.000000      13.000000      7.100000
# 75%      100.000000      17.000000     11.200000
# max      134.000000      21.000000  99999.000000

# %% [markdown]
# The maximum value of `'aisle_id'` is 134.

# %% [markdown]
# ### WHAT IS THE DATA TYPE OF `'department_id'`?

# %%
# dataframe info
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49693 entries, 1 to 49688
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_name   49677 non-null  object
#  1   aisle_id       49693 non-null  int64
#  2   department_id  49693 non-null  int64
#  3   prices         49693 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# The data type of `'department_id'` column is int64 (INTEGER).
